# %% [markdown]
# # Natural Language Processing using spacy

# %% [markdown]
# - How to Get Noun chunks
# - How to Get root words from Noun chunks
# - Lemmatization
# - Display tree view of words using displacy using displacy.render()
# - How to get the meaning of any denoted words by nlp using explain()
# - How to Find out NER(Named entity Recognition) in given doc
# - How to filter specific NER from raw data
# - Display Named Entity in doc using displacy.render
# - How to display only specific ENTITIES in displacy
# - How to Save Entities in html page and customize it as per need
# - find out total number of occurences of ORG entities
# - Remove stop_words/punctuation using is_stop & is_punct attribute
# - Try at Home
# ###### create a list of words/sentence after removing stop_words then make sentence
#
# ###### Sentence and Word Tokenization

# %%
import spacy as sp
from spacy import displacy # used for data visualization
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.attrs import ORTH # to be used for word count

# %%
sp.__version__
# Out:
# '3.2.1'

# %% [markdown]
# # To load english model

# %%
nlp = sp.load("en_core_web_sm") 
# ref: https://spacy.io/models/en
#!python -m spacy download en_core_web_sm

# %% [markdown]
# # To load english model

# %% [markdown]
# ## !python -m spacy download en_core_web_sm

# %% [markdown]
# ## Sample Text about Mr. Obama

# %%
txt = """Obama’s father, Barack Obama, Sr., was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government. Obama’s mother, S. Ann Dunham, grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and Barack Sr. met in a Russian language class at the University of Hawaii and married less than a year later.

When Obama was age two, Barack Sr. left to study at Harvard University; shortly thereafter, in 1964, Ann and Barack Sr. divorced. (Obama saw his father only one more time, during a brief visit when Obama was 10.) Later Ann remarried, this time to another foreign student, Lolo Soetoro from Indonesia, with whom she had a second child, Maya. Obama lived for several years in Jakarta with his half sister, mother, and stepfather. While there, Obama attended both a government-run school where he received some instruction in Islam and a Catholic private school where he took part in Christian schooling.

He returned to Hawaii in 1971 and lived in a modest apartment, sometimes with his grandparents and sometimes with his mother (she remained for a time in Indonesia, returned to Hawaii, and then went abroad again—partly to pursue work on a Ph.D.—before divorcing Soetoro in 1980). For a brief period his mother was aided by government food stamps, but the family mostly lived a middle-class existence. In 1979 Obama graduated from Punahou School, an elite college preparatory academy in Honolulu.

Obama attended Occidental College in suburban Los Angeles for two years and then transferred to Columbia University in New York City, where in 1983 he received a bachelor’s degree in political science. Influenced by professors who pushed him to take his studies more seriously, Obama experienced great intellectual growth during college and for a couple of years thereafter. He led a rather ascetic life and read works of literature and philosophy by William Shakespeare, Friedrich Nietzsche, Toni Morrison, and others. After serving for a couple of years as a writer and editor for Business International Corp., a research, publishing, and consulting firm in Manhattan, he took a position in 1985 as a community organizer on Chicago’s largely impoverished Far South Side. He returned to school three years later and graduated magna cum laude in 1991 from Harvard University’s law school, where he was the first African American to serve as president of the Harvard Law Review. While a summer associate in 1989 at the Chicago law firm of Sidley Austin, Obama had met Chicago native Michelle Robinson, a young lawyer at the firm. The two married in 1992."""

# %% [markdown]
# ## How to Get Noun chunks

# %%
obj = nlp(txt)
obj
# Out:
# Obama’s father, Barack Obama, Sr., was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government. Obama’s mother, S. Ann Dunham, grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and Barack Sr. met in a Russian language class at the University of Hawaii and married less than a year later.
#
# When Obama was age two, Barack Sr. left to study at Harvard University; shortly thereafter, in 1964, Ann and Barack Sr. divorced. (Obama saw his father only one more time, during a brief visit when Obama was 10.) Later Ann remarried, this time to another foreign student, Lolo Soetoro from Indonesia, with whom she had a second child, Maya. Obama lived for several years in Jakarta with his half sister, mother, and stepfather. While there, Obama attended both a government-run school where he received some instruction in Islam and a Catholic private school where he took part in Christian schooling.
#
# He returned to Hawaii in 1971 and lived in a modest apartment, sometimes with his grandparents and sometimes with his mother (she remained for a time in Indonesia, returned to Hawaii, and then went abroad again—partly to pursue work on a Ph.D.—before divorcing Soetoro in 1980). For a brief period his mother was aided by government food stamps, but the family mostly lived a middle-class existence. In 1979 Obama graduated from Punahou School, an elite college preparatory academy in Honolulu.
#
# Obama attended Occidental College in suburban Los Angeles for two years and then transferred to Columbia University in New York City, where in 1983 he received a bachelor’s degree in political science. Influenced by professors who pushed him to take his studies more seriously, Obama experienced great intellectual growth during college and for a couple of years thereafter. He led a rather ascetic life and read works of literature and philosophy by William Shakespeare, Friedrich Nietzsche, Toni Morrison, and others. After serving for a couple of years as a writer and editor for Business International Corp., a research, publishing, and consulting firm in Manhattan, he took a position in 1985 as a community organizer on Chicago’s largely impoverished Far South Side. He returned to school three years later and graduated magna cum laude in 1991 from Harvard University’s law school, where he was the first African American to serve as president of the Harvard Law Review. While a summer associate in 1989 at the Chicago law firm of Sidley Austin, Obama had met Chicago native Michelle Robinson, a young lawyer at the firm. The two married in 1992.

# %%
for n in obj.noun_chunks:
    print(n.text)
# Out:
# Obama’s father
# Barack Obama
# Sr
# .
# a teenage goatherd
# rural Kenya
# a scholarship
# the United States
# a senior economist
# the Kenyan government
# Obama’s mother
# S. Ann Dunham
# Kansas
# Texas
# Washington state
# her family
# Honolulu
# she
# Barack Sr
# .
# a Russian language class
# the University
# Hawaii
# Obama
# age
# Harvard University
# Ann
# Barack Sr
# Obama
# his father
# a brief visit
# Obama
# Ann
# another foreign student
# Lolo Soetoro
# Indonesia
# whom
# she
# a second child
# Maya
# Obama
# several years
# Jakarta
# his half sister
# mother
# stepfather
# Obama
# both a government-run school
# he
# some instruction
# Islam
# a Catholic private school
# he
# part
# Christian schooling
# He
# Hawaii
# a modest apartment
# his grandparents
# his mother
# she
# a time
# Indonesia
# Hawaii
# work
# Soetoro
# a brief period
# his mother
# government food stamps
# the family
# a middle-class existence
# Obama
# Punahou School
# an elite college preparatory academy
# Honolulu
# Obama
# Occidental College
# suburban Los Angeles
# two years
# Columbia University
# New York City
# he
# a bachelor’s degree
# political science
# professors
# who
# him
# his studies
# Obama
# great intellectual growth
# college
# a couple
# years
# He
# a rather ascetic life
# works
# literature
# philosophy
# William Shakespeare
# Friedrich Nietzsche
# Toni Morrison
# others
# a couple
# years
# a writer
# editor
# Business International Corp.
# a research
# publishing
# firm
# Manhattan
# he
# a position
# a community organizer
# Chicago
# largely impoverished Far South Side
# He
# school
# magna cum laude
# Harvard University’s law school
# he
# the first African American
# president
# the Harvard Law Review
# the Chicago law firm
# Sidley Austin
# Obama
# Chicago native Michelle Robinson
# a young lawyer
# the firm

# %% [markdown]
# ## How to Get root words from Noun chunks

# %%
for n in obj.noun_chunks:
    print(n.root)
# Out:
# father
# Obama
# Sr
# .
# goatherd
# Kenya
# scholarship
# States
# economist
# government
# mother
# Dunham
# Kansas
# Texas
# state
# family
# Honolulu
# she
# Sr
# .
# class
# University
# Hawaii
# Obama
# age
# University
# Ann
# Sr
# Obama
# father
# visit
# Obama
# Ann
# student
# Soetoro
# Indonesia
# whom
# she
# child
# Maya
# Obama
# years
# Jakarta
# sister
# mother
# stepfather
# Obama
# school
# he
# instruction
# Islam
# school
# he
# part
# schooling
# He
# Hawaii
# apartment
# grandparents
# mother
# she
# time
# Indonesia
# Hawaii
# work
# Soetoro
# period
# mother
# stamps
# family
# existence
# Obama
# School
# academy
# Honolulu
# Obama
# College
# Angeles
# years
# University
# City
# he
# degree
# science
# professors
# who
# him
# studies
# Obama
# growth
# college
# couple
# years
# He
# life
# works
# literature
# philosophy
# Shakespeare
# Nietzsche
# Morrison
# others
# couple
# years
# writer
# editor
# Corp.
# research
# publishing
# firm
# Manhattan
# he
# position
# organizer
# Chicago
# Side
# He
# school
# laude
# school
# he
# American
# president
# Review
# firm
# Austin
# Obama
# Robinson
# lawyer
# firm

# %% [markdown]
# ## Lemmatization

# %%
t2 = "Obama’s father, Barack Obama, Sr., was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government. Obama’s mother, S. Ann Dunham, grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and Barack Sr. met in a Russian language class at the University of Hawaii and married less than a year later."
t2
# Out:
# 'Obama’s father, Barack Obama, Sr., was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government. Obama’s mother, S. Ann Dunham, grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and Barack Sr. met in a Russian language class at the University of Hawaii and married less than a year later.'

# %%
obj2 = nlp(t2)
obj2
# Out:
# Obama’s father, Barack Obama, Sr., was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government. Obama’s mother, S. Ann Dunham, grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and Barack Sr. met in a Russian language class at the University of Hawaii and married less than a year later.

# %%
for w in obj2:
    print(w.lemma)
# Out:
# 4857242187112322394
# 614914527630368944
# 17071697760115891398
# 2593208677638477497
# 15388493565120789335
# 4857242187112322394
# 2593208677638477497
# 11009051309222302246
# 12646065887601541794
# 2593208677638477497
# 10382539506755952630
# 11901859001352538922
# 14903686835195047779
# 14155881130933041931
# 3002984154512732771
# 132814216812512435
# 4234016620340650456
# 2593208677638477497
# 471204509717844521
# 11901859001352538922
# 13838487344555440146
# 3791531372978436496
# 4251533498015236010
# 3002984154512732771
# 7425985699627899538
# 13226800834791099135
# 3278625293875499398
# 2593208677638477497
# 2283656566040971221
# 140282802797073706
# 12558846041070486771
# 11901859001352538922
# 17934676104927248284
# 705753312367543608
# 3002984154512732771
# 7425985699627899538
# 10833033741108051523
# 3625794390087546215
# 12646065887601541794
# 4857242187112322394
# 614914527630368944
# 7963322251145911254
# 2593208677638477497
# 14855555303352453619
# 13706867504515737279
# 2780745668230242118
# 2593208677638477497
# 17623831665190758874
# 2199259611705938403
# 3002984154512732771
# 8375283620274954233
# 2593208677638477497
# 1286636410600250842
# 2593208677638477497
# 2283656566040971221
# 8812112232444892211
# 12763746643991857148
# 11320251846592927908
# 4115755726172261197
# 18292453351080475948
# 6653326769694166608
# 3002984154512732771
# 1432168380107761110
# 12646065887601541794
# 3002984154512732771
# 3558769389704581913
# 6740321247510922449
# 2283656566040971221
# 15388493565120789335
# 11009051309222302246
# 12646065887601541794
# 6880656908171229526
# 3002984154512732771
# 11901859001352538922
# 135570813853780683
# 8740476009882919263
# 12859657019542931961
# 11667289587015813222
# 7425985699627899538
# 986123062041987797
# 886050111519832510
# 12533090343612149459
# 2283656566040971221
# 7769223299252587683
# 589070940943333110
# 10794458019344880855
# 11901859001352538922
# 14889849580704678361
# 7943840425043720459
# 12646065887601541794

# %%
for w in obj2:
    print((w.text, w.lemma_))
# Out:
# ('Obama', 'Obama')
# ('’s', '’s')
# ('father', 'father')
# (',', ',')
# ('Barack', 'Barack')
# ('Obama', 'Obama')
# (',', ',')
# ('Sr', 'Sr')
# ('.', '.')
# (',', ',')
# ('was', 'be')
# ('a', 'a')
# ('teenage', 'teenage')
# ('goatherd', 'goatherd')
# ('in', 'in')
# ('rural', 'rural')
# ('Kenya', 'Kenya')
# (',', ',')
# ('won', 'win')
# ('a', 'a')
# ('scholarship', 'scholarship')
# ('to', 'to')
# ('study', 'study')
# ('in', 'in')
# ('the', 'the')
# ('United', 'United')
# ('States', 'States')
# (',', ',')
# ('and', 'and')
# ('eventually', 'eventually')
# ('became', 'become')
# ('a', 'a')
# ('senior', 'senior')
# ('economist', 'economist')
# ('in', 'in')
# ('the', 'the')
# ('Kenyan', 'kenyan')
# ('government', 'government')
# ('.', '.')
# ('Obama', 'Obama')
# ('’s', '’s')
# ('mother', 'mother')
# (',', ',')
# ('S.', 'S.')
# ('Ann', 'Ann')
# ('Dunham', 'Dunham')
# (',', ',')
# ('grew', 'grow')
# ('up', 'up')
# ('in', 'in')
# ('Kansas', 'Kansas')
# (',', ',')
# ('Texas', 'Texas')
# (',', ',')
# ('and', 'and')
# ('Washington', 'Washington')
# ('state', 'state')
# ('before', 'before')
# ('her', 'her')
# ('family', 'family')
# ('settled', 'settle')
# ('in', 'in')
# ('Honolulu', 'Honolulu')
# ('.', '.')
# ('In', 'in')
# ('1960', '1960')
# ('she', 'she')
# ('and', 'and')
# ('Barack', 'Barack')
# ('Sr', 'Sr')
# ('.', '.')
# ('met', 'meet')
# ('in', 'in')
# ('a', 'a')
# ('Russian', 'russian')
# ('language', 'language')
# ('class', 'class')
# ('at', 'at')
# ('the', 'the')
# ('University', 'University')
# ('of', 'of')
# ('Hawaii', 'Hawaii')
# ('and', 'and')
# ('married', 'marry')
# ('less', 'less')
# ('than', 'than')
# ('a', 'a')
# ('year', 'year')
# ('later', 'later')
# ('.', '.')

# %% [markdown]
# ## Display tree view of words using displacy using displacy.render()

# %%
displacy.render(obj2)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d5a39845b79a43d8b2c9c7362abdf8e6-0" class="displacy" width="13350" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">father,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Barack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Obama,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Sr.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">teenage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">goatherd</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">rural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Kenya,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">won</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">scholarship</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">States,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">eventually</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">became</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">senior</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">economist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Kenyan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="current

# %%
displacy.render(obj2,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e55f191cc06d49e68fa58a0e4860cf48-0" class="displacy" width="13350" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">father,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Barack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Obama,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Sr.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">teenage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">goatherd</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">rural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Kenya,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">won</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">scholarship</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">States,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">eventually</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">became</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">senior</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">economist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">Kenyan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="current

# %% [markdown]
# ## How to get the meaning of any denoted words by nlp using explain()

# %%
sp.explain("PROPN")
# Out:
# 'proper noun'

# %%
sp.explain("DET")
# Out:
# 'determiner'

# %%
sp.explain("AUX")
# Out:
# 'auxiliary'

# %%
sp.explain("GPE")
# Out:
# 'Countries, cities, states'

# %% [markdown]
# ## How to Find out NER(Named entity Recognition) in given doc

# %%
obj
# Out:
# Obama’s father, Barack Obama, Sr., was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government. Obama’s mother, S. Ann Dunham, grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and Barack Sr. met in a Russian language class at the University of Hawaii and married less than a year later.
#
# When Obama was age two, Barack Sr. left to study at Harvard University; shortly thereafter, in 1964, Ann and Barack Sr. divorced. (Obama saw his father only one more time, during a brief visit when Obama was 10.) Later Ann remarried, this time to another foreign student, Lolo Soetoro from Indonesia, with whom she had a second child, Maya. Obama lived for several years in Jakarta with his half sister, mother, and stepfather. While there, Obama attended both a government-run school where he received some instruction in Islam and a Catholic private school where he took part in Christian schooling.
#
# He returned to Hawaii in 1971 and lived in a modest apartment, sometimes with his grandparents and sometimes with his mother (she remained for a time in Indonesia, returned to Hawaii, and then went abroad again—partly to pursue work on a Ph.D.—before divorcing Soetoro in 1980). For a brief period his mother was aided by government food stamps, but the family mostly lived a middle-class existence. In 1979 Obama graduated from Punahou School, an elite college preparatory academy in Honolulu.
#
# Obama attended Occidental College in suburban Los Angeles for two years and then transferred to Columbia University in New York City, where in 1983 he received a bachelor’s degree in political science. Influenced by professors who pushed him to take his studies more seriously, Obama experienced great intellectual growth during college and for a couple of years thereafter. He led a rather ascetic life and read works of literature and philosophy by William Shakespeare, Friedrich Nietzsche, Toni Morrison, and others. After serving for a couple of years as a writer and editor for Business International Corp., a research, publishing, and consulting firm in Manhattan, he took a position in 1985 as a community organizer on Chicago’s largely impoverished Far South Side. He returned to school three years later and graduated magna cum laude in 1991 from Harvard University’s law school, where he was the first African American to serve as president of the Harvard Law Review. While a summer associate in 1989 at the Chicago law firm of Sidley Austin, Obama had met Chicago native Michelle Robinson, a young lawyer at the firm. The two married in 1992.

# %%
for ner in obj.ents:
    print((ner,ner.label_))
# Out:
# (Obama’s, 'PERSON')
# (Barack Obama, Sr., 'PERSON')
# (Kenya, 'GPE')
# (the United States, 'GPE')
# (Kenyan, 'NORP')
# (Obama’s, 'ORG')
# (S. Ann Dunham, 'PERSON')
# (Kansas, 'GPE')
# (Texas, 'GPE')
# (Washington, 'GPE')
# (Honolulu, 'GPE')
# (1960, 'DATE')
# (Barack Sr., 'PERSON')
# (Russian, 'LANGUAGE')
# (the University of Hawaii, 'ORG')
# (less than a year later, 'DATE')
# (Obama, 'GPE')
# (age two, 'DATE')
# (Barack Sr., 'PERSON')
# (Harvard University, 'ORG')
# (1964, 'DATE')
# (Barack Sr., 'PERSON')
# (Obama, 'PERSON')
# (only one, 'CARDINAL')
# (Obama, 'GPE')
# (10, 'CARDINAL')
# (Lolo Soetoro, 'PERSON')
# (Indonesia, 'GPE')
# (second, 'ORDINAL')
# (Maya, 'PERSON')
# (Obama, 'PERSON')
# (several years, 'DATE')
# (Jakarta, 'GPE')
# (half, 'CARDINAL')
# (Obama, 'PERSON')
# (Islam, 'ORG')
# (Catholic, 'NORP')
# (Christian, 'NORP')
# (Hawaii, 'GPE')
# (1971, 'DATE')
# (Indonesia, 'GPE')
# (Hawaii, 'GPE')
# (Soetoro, 'PERSON')
# (1980, 'DATE')
# (1979, 'DATE')
# (Obama, 'GPE')
# (Punahou School, 'ORG')
# (Honolulu, 'GPE')
# (Obama, 'PERSON')
# (Occidental College, 'ORG')
# (Los Angeles, 'GPE')
# (two years, 'DATE')
# (Columbia University, 'ORG')
# (New York City, 'GPE')
# (1983, 'DATE')
# (Obama, 'PERSON')
# (a couple of years, 'DATE')
# (William Shakespeare, 'PERSON')
# (Friedrich Nietzsche, 'PERSON')
# (Toni Morrison, 'PERSON')
# (a couple of years, 'DATE')
# (Business International Corp., 'ORG')
# (Manhattan, 'GPE')
# (1985, 'DATE')
# (Chicago, 'GPE')
# (Far South Side, 'FAC')
# (three years later, 'DATE')
# (1991, 'DATE')
# (Harvard University’s, 'ORG')
# (first, 'ORDINAL')
# (African American, 'NORP')
# (the Harvard Law Review, 'ORG')
# (summer, 'DATE')
# (1989, 'DATE')
# (Chicago, 'GPE')
# (Sidley Austin, 'PERSON')
# (Obama, 'GPE')
# (Chicago, 'GPE')
# (Michelle Robinson, 'PERSON')
# (two, 'CARDINAL')
# (1992, 'DATE')

# %% [markdown]
# ## Another way to get NER

# %%
for w in obj:
    print((w.text, w.ent_type_))
# Out:
# ('Obama', 'PERSON')
# ('’s', 'PERSON')
# ('father', '')
# (',', '')
# ('Barack', 'PERSON')
# ('Obama', 'PERSON')
# (',', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# (',', '')
# ('was', '')
# ('a', '')
# ('teenage', '')
# ('goatherd', '')
# ('in', '')
# ('rural', '')
# ('Kenya', 'GPE')
# (',', '')
# ('won', '')
# ('a', '')
# ('scholarship', '')
# ('to', '')
# ('study', '')
# ('in', '')
# ('the', 'GPE')
# ('United', 'GPE')
# ('States', 'GPE')
# (',', '')
# ('and', '')
# ('eventually', '')
# ('became', '')
# ('a', '')
# ('senior', '')
# ('economist', '')
# ('in', '')
# ('the', '')
# ('Kenyan', 'NORP')
# ('government', '')
# ('.', '')
# ('Obama', 'ORG')
# ('’s', 'ORG')
# ('mother', '')
# (',', '')
# ('S.', 'PERSON')
# ('Ann', 'PERSON')
# ('Dunham', 'PERSON')
# (',', '')
# ('grew', '')
# ('up', '')
# ('in', '')
# ('Kansas', 'GPE')
# (',', '')
# ('Texas', 'GPE')
# (',', '')
# ('and', '')
# ('Washington', 'GPE')
# ('state', '')
# ('before', '')
# ('her', '')
# ('family', '')
# ('settled', '')
# ('in', '')
# ('Honolulu', 'GPE')
# ('.', '')
# ('In', '')
# ('1960', 'DATE')
# ('she', '')
# ('and', '')
# ('Barack', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# ('met', '')
# ('in', '')
# ('a', '')
# ('Russian', 'LANGUAGE')
# ('language', '')
# ('class', '')
# ('at', '')
# ('the', 'ORG')
# ('University', 'ORG')
# ('of', 'ORG')
# ('Hawaii', 'ORG')
# ('and', '')
# ('married', '')
# ('less', 'DATE')
# ('than', 'DATE')
# ('a', 'DATE')
# ('year', 'DATE')
# ('later', 'DATE')
# ('.', '')
# ('\n\n', '')
# ('When', '')
# ('Obama', 'GPE')
# ('was', '')
# ('age', 'DATE')
# ('two', 'DATE')
# (',', '')
# ('Barack', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# ('left', '')
# ('to', '')
# ('study', '')
# ('at', '')
# ('Harvard', 'ORG')
# ('University', 'ORG')
# (';', '')
# ('shortly', '')
# ('thereafter', '')
# (',', '')
# ('in', '')
# ('1964', 'DATE')
# (',', '')
# ('Ann', '')
# ('and', '')
# ('Barack', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# ('divorced', '')
# ('.', '')
# ('(', '')
# ('Obama', 'PERSON')
# ('saw', '')
# ('his', '')
# ('father', '')
# ('only', 'CARDINAL')
# ('one', 'CARDINAL')
# ('more', '')
# ('time', '')
# (',', '')
# ('during', '')
# ('a', '')
# ('brief', '')
# ('visit', '')
# ('when', '')
# ('Obama', 'GPE')
# ('was', '')
# ('10', 'CARDINAL')
# ('.', '')
# (')', '')
# ('Later', '')
# ('Ann', '')
# ('remarried', '')
# (',', '')
# ('this', '')
# ('time', '')
# ('to', '')
# ('another', '')
# ('foreign', '')
# ('student', '')
# (',', '')
# ('Lolo', 'PERSON')
# ('Soetoro', 'PERSON')
# ('from', '')
# ('Indonesia', 'GPE')
# (',', '')
# ('with', '')
# ('whom', '')
# ('she', '')
# ('had', '')
# ('a', '')
# ('second', 'ORDINAL')
# ('child', '')
# (',', '')
# ('Maya', 'PERSON')
# ('.', '')
# ('Obama', 'PERSON')
# ('lived', '')
# ('for', '')
# ('several', 'DATE')
# ('years', 'DATE')
# ('in', '')
# ('Jakarta', 'GPE')
# ('with', '')
# ('his', '')
# ('half', 'CARDINAL')
# ('sister', '')
# (',', '')
# ('mother', '')
# (',', '')
# ('and', '')
# ('stepfather', '')
# ('.', '')
# ('While', '')
# ('there', '')
# (',', '')
# ('Obama', 'PERSON')
# ('attended', '')
# ('both', '')
# ('a', '')
# ('government', '')
# ('-', '')
# ('run', '')
# ('school', '')
# ('where', '')
# ('he', '')
# ('received', '')
# ('some', '')
# ('instruction', '')
# ('in', '')
# ('Islam', 'ORG')
# ('and', '')
# ('a', '')
# ('Catholic', 'NORP')
# ('private', '')
# ('school', '')
# ('where', '')
# ('he', '')
# ('took', '')
# ('part', '')
# ('in', '')
# ('Christian', 'NORP')
# ('schooling', '')
# ('.', '')
# ('\n\n', '')
# ('He', '')
# ('returned', '')
# ('to', '')
# ('Hawaii', 'GPE')
# ('in', '')
# ('1971', 'DATE')
# ('and', '')
# ('lived', '')
# ('in', '')
# ('a', '')
# ('modest', '')
# ('apartment', '')
# (',', '')
# ('sometimes', '')
# ('with', '')
# ('his', '')
# ('grandparents', '')
# ('and', '')
# ('sometimes', '')
# ('with', '')
# ('his', '')
# ('mother', '')
# ('(', '')
# ('she', '')
# ('remained', '')
# ('for', '')
# ('a', '')
# ('time', '')
# ('in', '')
# ('Indonesia', 'GPE')
# (',', '')
# ('returned', '')
# ('to', '')
# ('Hawaii', 'GPE')
# (',', '')
# ('and', '')
# ('then', '')
# ('went', '')
# ('abroad', '')
# ('again', '')
# ('—', '')
# ('partly', '')
# ('to', '')
# ('pursue', '')
# ('work', '')
# ('on', '')
# ('a', '')
# ('Ph', '')
# ('.', '')
# ('D.—before', '')
# ('divorcing', '')
# ('Soetoro', 'PERSON')
# ('in', '')
# ('1980', 'DATE')
# (')', '')
# ('.', '')
# ('For', '')
# ('a', '')
# ('brief', '')
# ('period', '')
# ('his', '')
# ('mother', '')
# ('was', '')
# ('aided', '')
# ('by', '')
# ('government', '')
# ('food', '')
# ('stamps', '')
# (',', '')
# ('but', '')
# ('the', '')
# ('family', '')
# ('mostly', '')
# ('lived', '')
# ('a', '')
# ('middle', '')
# ('-', '')
# ('class', '')
# ('existence', '')
# ('.', '')
# ('In', '')
# ('1979', 'DATE')
# ('Obama', 'GPE')
# ('graduated', '')
# ('from', '')
# ('Punahou', 'ORG')
# ('School', 'ORG')
# (',', '')
# ('an', '')
# ('elite', '')
# ('college', '')
# ('preparatory', '')
# ('academy', '')
# ('in', '')
# ('Honolulu', 'GPE')
# ('.', '')
# ('\n\n', '')
# ('Obama', 'PERSON')
# ('attended', '')
# ('Occidental', 'ORG')
# ('College', 'ORG')
# ('in', '')
# ('suburban', '')
# ('Los', 'GPE')
# ('Angeles', 'GPE')
# ('for', '')
# ('two', 'DATE')
# ('years', 'DATE')
# ('and', '')
# ('then', '')
# ('transferred', '')
# ('to', '')
# ('Columbia', 'ORG')
# ('University', 'ORG')
# ('in', '')
# ('New', 'GPE')
# ('York', 'GPE')
# ('City', 'GPE')
# (',', '')
# ('where', '')
# ('in', '')
# ('1983', 'DATE')
# ('he', '')
# ('received', '')
# ('a', '')
# ('bachelor', '')
# ('’s', '')
# ('degree', '')
# ('in', '')
# ('political', '')
# ('science', '')
# ('.', '')
# ('Influenced', '')
# ('by', '')
# ('professors', '')
# ('who', '')
# ('pushed', '')
# ('him', '')
# ('to', '')
# ('take', '')
# ('his', '')
# ('studies', '')
# ('more', '')
# ('seriously', '')
# (',', '')
# ('Obama', 'PERSON')
# ('experienced', '')
# ('great', '')
# ('intellectual', '')
# ('growth', '')
# ('during', '')
# ('college', '')
# ('and', '')
# ('for', '')
# ('a', 'DATE')
# ('couple', 'DATE')
# ('of', 'DATE')
# ('years', 'DATE')
# ('thereafter', '')
# ('.', '')
# ('He', '')
# ('led', '')
# ('a', '')
# ('rather', '')
# ('ascetic', '')
# ('life', '')
# ('and', '')
# ('read', '')
# ('works', '')
# ('of', '')
# ('literature', '')
# ('and', '')
# ('philosophy', '')
# ('by', '')
# ('William', 'PERSON')
# ('Shakespeare', 'PERSON')
# (',', '')
# ('Friedrich', 'PERSON')
# ('Nietzsche', 'PERSON')
# (',', '')
# ('Toni', 'PERSON')
# ('Morrison', 'PERSON')
# (',', '')
# ('and', '')
# ('others', '')
# ('.', '')
# ('After', '')
# ('serving', '')
# ('for', '')
# ('a', 'DATE')
# ('couple', 'DATE')
# ('of', 'DATE')
# ('years', 'DATE')
# ('as', '')
# ('a', '')
# ('writer', '')
# ('and', '')
# ('editor', '')
# ('for', '')
# ('Business', 'ORG')
# ('International', 'ORG')
# ('Corp.', 'ORG')
# (',', '')
# ('a', '')
# ('research', '')
# (',', '')
# ('publishing', '')
# (',', '')
# ('and', '')
# ('consulting', '')
# ('firm', '')
# ('in', '')
# ('Manhattan', 'GPE')
# (',', '')
# ('he', '')
# ('took', '')
# ('a', '')
# ('position', '')
# ('in', '')
# ('1985', 'DATE')
# ('as', '')
# ('a', '')
# ('community', '')
# ('organizer', '')
# ('on', '')
# ('Chicago', 'GPE')
# ('’s', '')
# ('largely', '')
# ('impoverished', '')
# ('Far', 'FAC')
# ('South', 'FAC')
# ('Side', 'FAC')
# ('.', '')
# ('He', '')
# ('returned', '')
# ('to', '')
# ('school', '')
# ('three', 'DATE')
# ('years', 'DATE')
# ('later', 'DATE')
# ('and', '')
# ('graduated', '')
# ('magna', '')
# ('cum', '')
# ('laude', '')
# ('in', '')
# ('1991', 'DATE')
# ('from', '')
# ('Harvard', 'ORG')
# ('University', 'ORG')
# ('’s', 'ORG')
# ('law', '')
# ('school', '')
# (',', '')
# ('where', '')
# ('he', '')
# ('was', '')
# ('the', '')
# ('first', 'ORDINAL')
# ('African', 'NORP')
# ('American', 'NORP')
# ('to', '')
# ('serve', '')
# ('as', '')
# ('president', '')
# ('of', '')
# ('the', 'ORG')
# ('Harvard', 'ORG')
# ('Law', 'ORG')
# ('Review', 'ORG')
# ('.', '')
# ('While', '')
# ('a', '')
# ('summer', 'DATE')
# ('associate', '')
# ('in', '')
# ('1989', 'DATE')
# ('at', '')
# ('the', '')
# ('Chicago', 'GPE')
# ('law', '')
# ('firm', '')
# ('of', '')
# ('Sidley', 'PERSON')
# ('Austin', 'PERSON')
# (',', '')
# ('Obama', 'GPE')
# ('had', '')
# ('met', '')
# ('Chicago', 'GPE')
# ('native', '')
# ('Michelle', 'PERSON')
# ('Robinson', 'PERSON')
# (',', '')
# ('a', '')
# ('young', '')
# ('lawyer', '')
# ('at', '')
# ('the', '')
# ('firm', '')
# ('.', '')
# ('The', '')
# ('two', 'CARDINAL')
# ('married', '')
# ('in', '')
# ('1992', 'DATE')
# ('.', '')

# %% [markdown]
# ## How to filter specific NER from raw data

# %%
for w in obj:
    if w.ent_type_ == "PERSON":
        print((w.text,w.ent_type_))
# Out:
# ('Obama', 'PERSON')
# ('’s', 'PERSON')
# ('Barack', 'PERSON')
# ('Obama', 'PERSON')
# (',', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# ('S.', 'PERSON')
# ('Ann', 'PERSON')
# ('Dunham', 'PERSON')
# ('Barack', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# ('Barack', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# ('Barack', 'PERSON')
# ('Sr', 'PERSON')
# ('.', 'PERSON')
# ('Obama', 'PERSON')
# ('Lolo', 'PERSON')
# ('Soetoro', 'PERSON')
# ('Maya', 'PERSON')
# ('Obama', 'PERSON')
# ('Obama', 'PERSON')
# ('Soetoro', 'PERSON')
# ('Obama', 'PERSON')
# ('Obama', 'PERSON')
# ('William', 'PERSON')
# ('Shakespeare', 'PERSON')
# ('Friedrich', 'PERSON')
# ('Nietzsche', 'PERSON')
# ('Toni', 'PERSON')
# ('Morrison', 'PERSON')
# ('Sidley', 'PERSON')
# ('Austin', 'PERSON')
# ('Michelle', 'PERSON')
# ('Robinson', 'PERSON')

# %%
for w in obj:
    if w.ent_type_ == "CARDINAL":
        print((w.text,w.ent_type_))
# Out:
# ('only', 'CARDINAL')
# ('one', 'CARDINAL')
# ('10', 'CARDINAL')
# ('half', 'CARDINAL')
# ('two', 'CARDINAL')

# %% [markdown]
# ## Display Named Entity in doc using displacy.render

# %%
displacy.render(obj,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  father,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Obama, Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , was a teenage goatherd in rural
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kenya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , won a scholarship to study in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and eventually became a senior economist in the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kenyan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  mother,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S. Ann Dunham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , grew up in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kansas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  state before her family settled in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Honolulu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1960
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  she and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  met in a
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#  language class at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Hawaii
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and married
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     less than a year later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br></br>When
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     age two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  left to study at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harvard University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; shortly thereafter, in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1964
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Ann and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  divorced. (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  saw his father
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  more time, during a brief visit when
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; fo

# %% [markdown]
# ## How to display only specific ENTITIES in displacy

# %%
displacy.render(obj,style="ent",options={"ents":["person"]})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  father,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Obama, Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government. Obama’s mother,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S. Ann Dunham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  met in a Russian language class at the University of Hawaii and married less than a year later.</br></br>When Obama was age two,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  left to study at Harvard University; shortly thereafter, in 1964, Ann and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  divorced. (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  saw his father only one more time, during a brief visit when Obama was 10.) Later Ann remarried, this time to another foreign student,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lolo Soetoro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from Indonesia, with whom she had a second child,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  lived for several years in Jakarta with his half sister, mother, and stepfather. While there,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  attended both a government-run school where he received some instruction in Islam and a Catholic private school where he took part in Christian schooling.</br></br>He returned to Hawaii in 1971 and lived in a modest apartment, sometimes with his grandparents and sometimes with his mother (she remained for a time in Indonesia, returned to Hawaii, and then went abroad again—partly to pursue work on a Ph.D.—before divorcing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Soetoro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in 1980). For a brief period his mother was aided by government food stamps, but the family mostly lived a middle-class existence. In 1979 Obama graduated from Punahou School, an elite college preparatory academy in Honolulu.</br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  attended Occidental College in suburban Los Angeles for two years and then transferred to Columbia University in New York City, where in 1983 he received a bachelor’s degree in political science. Influenced by professors who pushed him to take his studies more seriously,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  experienced great intellectual growth during college and for a couple of years thereafter. He led a rather ascetic life and read works of literature and philosophy by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William Shakespeare
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friedrich Nietzsche
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Morrison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and others. After serving for a couple of years as a writer and editor for Business International Corp., a research, publishing, and consulting firm in Manhattan, he took a position in 1985 as a community organizer on Chicago’s largely impoverished Far South Side. He returned to school three years later and graduated magna cum laude in 1991 from Harvard University’s law school, where he was the first African American to serve as president of the Harvard Law Review. While a summer associate in 1989 at the Chicago law firm of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sidley Austin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle;

# %%
displacy.render(obj,style="ent",options={"ents":["person","cardinal","ORG"]})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  father,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Obama, Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , was a teenage goatherd in rural Kenya, won a scholarship to study in the United States, and eventually became a senior economist in the Kenyan government.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  mother,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S. Ann Dunham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , grew up in Kansas, Texas, and Washington state before her family settled in Honolulu. In 1960 she and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  met in a Russian language class at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Hawaii
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and married less than a year later.</br></br>When Obama was age two,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  left to study at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harvard University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; shortly thereafter, in 1964, Ann and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Sr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  divorced. (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  saw his father
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  more time, during a brief visit when Obama was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .) Later Ann remarried, this time to another foreign student,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lolo Soetoro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from Indonesia, with whom she had a second child,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  lived for several years in Jakarta with his
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  sister, mother, and stepfather. While there,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  attended both a government-run school where he received some instruction in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Islam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and a Catholic private school where he took part in Christian schooling.</br></br>He returned to Hawaii in 1971 and lived in a modest apartment, sometimes with his grandparents and sometimes with his mother (she remained for a time in Indonesia, returned to Hawaii, and then went abroad again—partly to pursue work on a Ph.D.—before divorcing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Soetoro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in 1980). For a brief period his mother was aided by government food stamps, but the family mostly lived a middle-class existence. In 1979 Obama graduated from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Punahou School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , an elite college preparatory academy in Honolulu.</br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  attended
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; bord

# %% [markdown]
# ## How to Save Entities in html page and customize it as per need

# %%
html = displacy.render(obj,style="ent",jupyter=False)

# %%
with open("display_ner.html","w") as fo:
    fo.write(html)

# %%
# !pwd
# Out:
# /Users/pksoni/Documents/{{Documents}}/Python_Prog/for_pycsr/04_Python_for_DataScience/NLP

# %% [markdown]
# ## find out total number of occurences of ORG entities

# %%
op = [1 for w in obj if w.ent_type_ == "ORG"]
sum(op)
# Out:
# 25

# %%
op = [1 for w in obj if w.ent_type_ == "PERSON"]
sum(op)
# Out:
# 38

# %%
op = [1 for w in obj if w.ent_type_ == "CARDINAL"]
sum(op)
# Out:
# 5

# %%
op = [1 for w in obj if w.ent_type_ == "GPE"]
sum(op)
# Out:
# 27

# %% [markdown]
# ## Remove stop_words/punctuation using is_stop & is_punct attribute

# %%
op = [w.text for w in obj if not w.is_stop and not w.is_punct]
print(op)
# Out:
# ['Obama', 'father', 'Barack', 'Obama', 'Sr', 'teenage', 'goatherd', 'rural', 'Kenya', 'won', 'scholarship', 'study', 'United', 'States', 'eventually', 'senior', 'economist', 'Kenyan', 'government', 'Obama', 'mother', 'S.', 'Ann', 'Dunham', 'grew', 'Kansas', 'Texas', 'Washington', 'state', 'family', 'settled', 'Honolulu', '1960', 'Barack', 'Sr', 'met', 'Russian', 'language', 'class', 'University', 'Hawaii', 'married', 'year', 'later', '\n\n', 'Obama', 'age', 'Barack', 'Sr', 'left', 'study', 'Harvard', 'University', 'shortly', '1964', 'Ann', 'Barack', 'Sr', 'divorced', 'Obama', 'saw', 'father', 'time', 'brief', 'visit', 'Obama', '10', 'Later', 'Ann', 'remarried', 'time', 'foreign', 'student', 'Lolo', 'Soetoro', 'Indonesia', 'second', 'child', 'Maya', 'Obama', 'lived', 'years', 'Jakarta', 'half', 'sister', 'mother', 'stepfather', 'Obama', 'attended', 'government', 'run', 'school', 'received', 'instruction', 'Islam', 'Catholic', 'private', 'school', 'took', 'Christian', 'schooling', '\n\n', 'returned', 'Hawaii', '1971', 'lived', 'modest', 'apartment', 'grandparents', 'mother', 'remained', 'time', 'Indonesia', 'returned', 'Hawaii', 'went', 'abroad', 'partly', 'pursue', 'work', 'Ph', 'D.—before', 'divorcing', 'Soetoro', '1980', 'brief', 'period', 'mother', 'aided', 'government', 'food', 'stamps', 'family', 'lived', 'middle', 'class', 'existence', '1979', 'Obama', 'graduated', 'Punahou', 'School', 'elite', 'college', 'preparatory', 'academy', 'Honolulu', '\n\n', 'Obama', 'attended', 'Occidental', 'College', 'suburban', 'Los', 'Angeles', 'years', 'transferred', 'Columbia', 'University', 'New', 'York', 'City', '1983', 'received', 'bachelor', 'degree', 'political', 'science', 'Influenced', 'professors', 'pushed', 'studies', 'seriously', 'Obama', 'experienced', 'great', 'intellectual', 'growth', 'college', 'couple', 'years', 'led', 'ascetic', 'life', 'read', 'works', 'literature', 'philosophy', 'William', 'Shakespeare', 'Friedrich', 'Nietzsche', 'Toni', 'Morrison', 'serving', 'couple', 'years', 'writer', 'editor', 'Business', 'International', 'Corp.', 'research', 'publishing', 'consulting', 'firm', 'Manhattan', 'took', 'position', '1985', 'community', 'organizer', 'Chicago', 'largely', 'impoverished', 'Far', 'South', 'returned', 'school', 'years', 'later', 'graduated', 'magna', 'cum', 'laude', '1991', 'Harvard', 'University', 'law', 'school', 'African', 'American', 'serve', 'president', 'Harvard', 'Law', 'Review', 'summer', 'associate', '1989', 'Chicago', 'law', 'firm', 'Sidley', 'Austin', 'Obama', 'met', 'Chicago', 'native', 'Michelle', 'Robinson', 'young', 'lawyer', 'firm', 'married', '1992']

# %% [markdown]
# # Try at Home
# ###### create a list of words/sentence after removing stop_words then make sentence
#
# ###### Sentence and Word Tokenization
